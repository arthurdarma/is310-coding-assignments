# %%
import pandas as pd
df=pd.read_csv('graybook-fa23.csv')
df.sample(20)
# Out:
#                   Employee Name                    Job Title Tenure  \
# 3026              Elbel, Stefan                 CO-DIR, ACRC    NaN
# 2095          Herbold, T Joshua              ASSOC HEAD ACCY    NaN
# 1709           Colacicco, Frank  ASSOC DIR, UTILITY DISTRBTN    NaN
# 2484   Spinnato, Jake Alexander              UGRAD ACAD ADVR    NaN
# 2766             Moulin, Pierre                    PROF, CSL    NaN
# 192        Post, Nathan Matthew              RES SPEC IN AGR    NaN
# 292         Gasper, Susan Marie      EXT EDUC, STEM/CHEM III    NaN
# 4367   Soeken-Gittinger, Lori A            AQUATIC ECOLOGIST    NaN
# 4299         Jarvis, Janet Lynn           ASSOC RES SCI, GIS    NaN
# 5175            Shubert, Thomas                 SR ASSOC DIR    NaN
# 218       Bautista, Bianca Adia  VST EXT EDUC, FAM CNSMR SCI    NaN
# 5621        Caldrone, Sandi Lee       ASST PROF UNIV LIBRARY    NaN
# 4695         Kantola, Ilsa Beth                  VST RES SCI    NaN
# ...

# %%
df["Job Title"].value_counts().head(30)
# Out:
# Job Title
# PROF                         582
# ASSOC PROF                   453
# ASST PROF                    436
# CLIN ASST PROF, CI MED       133
# LECTURER                      93
# TCH ASST PROF                 79
# CLIN ASST PROF                69
# POSTDOC RES ASSOC             67
# PROF, CI MED                  65
# SR LECTURER                   56
# ACAD ADVR                     50
# CLIN ASSOC PROF, CI MED       50
# RES SCI                       39
# CLIN ASSOC PROF               39
# INSTR                         37
# TEACHING ASST PROF            36
# RES ASST PROF                 34
# HEAD                          33
# PROF, CSL                     29
# TCH ASSOC                     28
# TCH ASSOC PROF                26
# ASSOC DIR                     25
# CLIN PROF                     24
# ACAD PRFNL - ASSOC            22
# PROF, MRL                     22
# CLIN COUNS                    22
# VET RES SPEC                  20
# RES ASSOC PROF                18
# ...
